# %% [markdown]
# ### Here we are going to build and prototype the classifier

# %% [markdown]
# #### Start with importing the required modules

# %%
import re
import unidecode
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, recall_score, precision_score
import xgboost as xgb
from xgboost import plot_importance
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import seaborn as snsz
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.neural_network import MLPClassifier
import pickle

# %% [markdown]
# #### Now we need to setup a ref to the database

# %%
cred = credentials.Certificate('recipe-recommendation-94b2e-e2e0a9ee33eb.json')
firebase_admin.initialize_app(cred)

db = firestore.client()

# %% [markdown]
# #### Lets now fetch the data

# %%
reviewRef = db.collection(u'reviews')
profile_docs = reviewRef.stream()

df = pd.DataFrame()

for doc in profile_docs:
    temp = pd.DataFrame(doc.to_dict(), index=1)
    df.append(temp)

# %% [markdown]
# #### Here we can alternativly load from the local csv, dowloaded for consitency

# %%
review_df = pd.read_csv('TestDataNew.csv')
review_df = review_df.drop(review_df.columns[0], axis=1)

# %% [markdown]
# #### Lets now perform a preliminary overview

# %%
pd.value_counts(review_df['condition']).plot.bar()

# %%
pd.value_counts(review_df['relief']).plot.bar()

# %%
plt.figure(figsize=(10,8))
ax = sns.violinplot(x="condition", y="thc_percent", data=review_df)
ax.set_title("Distribution of THC for each condition",fontsize= 15, fontweight='bold')
ax.set_ylabel("Relief", fontsize= 12, fontweight='bold')
ax.set_xticklabels(labels =['cramps', 'depression', 'eye_pressure', 'fatigue_headaches', 'inflamation_insomnia', 'lack_appetite', 'muscle_spasms', 'nausea', 'pain', 'seizures', 'spasticity', 'stress'])
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [Text(0,0,'cramps'),
#  Text(0,0,'depression'),
#  Text(0,0,'eye_pressure'),
#  Text(0,0,'fatigue_headaches'),
#  Text(0,0,'inflamation_insomnia'),
#  Text(0,0,'lack_appetite'),
#  Text(0,0,'muscle_spasms'),
#  Text(0,0,'nausea'),
#  Text(0,0,'pain'),
#  Text(0,0,'seizures'),
#  Text(0,0,'spasticity'),
#  Text(0,0,'stress')]

# %%
plt.figure(figsize=(10,8))
ax = sns.violinplot(x="condition", y="cbd_percent", data=review_df)
ax.set_title("Distribution of CBD for each condition",fontsize= 15, fontweight='bold')
ax.set_ylabel("Relief", fontsize= 12, fontweight='bold')
ax.set_xticklabels(labels =['cramps', 'depression', 'eye_pressure', 'fatigue_headaches', 'inflamation_insomnia', 'lack_appetite', 'muscle_spasms', 'nausea', 'pain', 'seizures', 'spasticity', 'stress'])
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [Text(0,0,'cramps'),
#  Text(0,0,'depression'),
#  Text(0,0,'eye_pressure'),
#  Text(0,0,'fatigue_headaches'),
#  Text(0,0,'inflamation_insomnia'),
#  Text(0,0,'lack_appetite'),
#  Text(0,0,'muscle_spasms'),
#  Text(0,0,'nausea'),
#  Text(0,0,'pain'),
#  Text(0,0,'seizures'),
#  Text(0,0,'spasticity'),
#  Text(0,0,'stress')]

# %% [markdown]
# #### Lets now prepare the data to be used in the classifier

# %%
# First lets get a list of the headings
list(review_df)
# Out:
# ['username',
#  'comment',
#  'rating',
#  'strain_id',
#  'commnet_polarity',
#  'comment_subjectivity',
#  'hybrid',
#  'sativa',
#  'indica',
#  'thc_percent',
#  'cbd_percent',
#  'avg_subjectivity',
#  'avg_polarity',
#  'avg_rating',
#  'cooking_time_min',
#  'is_desert',
#  'oven_percentage_power',
#  'percent_serving_weight_weed_ingredient',
#  'uses_butter',
#  'uses_oil',
#  'condition',
#  'relief']

# %%
# Lets first remove all attributes that wont be used as inputs in the algorithm
review_df = review_df.drop(['strain_id','username', 'comment', 'strain_id', 'commnet_polarity', 'comment_subjectivity', 'rating'], axis=1)

# %%
# Convert bools to ints
review_df['hybrid'] = review_df.hybrid.astype(float)
review_df['sativa'] = review_df.sativa.astype(float)
review_df['indica'] = review_df.indica.astype(float)
review_df['is_desert'] = review_df.is_desert.astype(float)
review_df['uses_butter'] = review_df.uses_butter.astype(float)
review_df['uses_oil'] = review_df.uses_oil.astype(float)
review_df['relief'] = review_df.relief.astype(int)

# %%
# Lets now normalize the floating point attirbutes between 0-1 that needs it 
review_df['cooking_time_min'] = (review_df['cooking_time_min']-review_df['cooking_time_min'].min()) / (review_df['cooking_time_min'].max()-review_df['cooking_time_min'].min())
review_df['thc_percent'] = (review_df['thc_percent']-review_df['thc_percent'].min()) / (review_df['thc_percent'].max()-review_df['thc_percent'].min())
review_df['cbd_percent'] = (review_df['cbd_percent']-review_df['cbd_percent'].min()) / (review_df['cbd_percent'].max()-review_df['cbd_percent'].min())
review_df['avg_subjectivity'] = (review_df['avg_subjectivity']-review_df['avg_subjectivity'].min()) / (review_df['avg_subjectivity'].max()-review_df['avg_subjectivity'].min())
review_df['avg_polarity'] = (review_df['avg_polarity']-review_df['avg_polarity'].min()) / (review_df['avg_polarity'].max()-review_df['avg_polarity'].min())
review_df['avg_rating'] = (review_df['avg_rating']-review_df['avg_rating'].min()) / (review_df['avg_rating'].max()-review_df['avg_rating'].min())
review_df['oven_percentage_power'] = (review_df['oven_percentage_power']-review_df['oven_percentage_power'].min()) / (review_df['oven_percentage_power'].max()-review_df['oven_percentage_power'].min())
review_df['percent_serving_weight_weed_ingredient'] = (review_df['percent_serving_weight_weed_ingredient']-review_df['percent_serving_weight_weed_ingredient'].min()) / (review_df['percent_serving_weight_weed_ingredient'].max()-review_df['percent_serving_weight_weed_ingredient'].min())

# %%
# We now need to flatmap the condition into binary indicators for each condition
review_df = pd.get_dummies(review_df, columns=['condition'])

# %%
# Here we can bin the oven temp variable
bins = [-np.inf, 0.65, 0.8, 1.0]
labels=['cool','moderate','hot']
review_df['oven_power_cat'] = pd.cut(review_df.oven_percentage_power, bins=bins, labels=labels)

# %%
review_df = pd.get_dummies(review_df, columns=['oven_power_cat'])

# %%
review_df = review_df.drop(['oven_percentage_power'], axis=1)

# %% [markdown]
# ### Now we can begin training our models

# %% [markdown]
# #### Lets start with XGBoost (Gradient boosted trees)

# %%
data_df = review_df.drop(['relief'], axis=1)

# %%
# Here we can create our train test split
X_train, X_test, y_train, y_test = train_test_split(data_df,review_df["relief"], test_size = 0.25, random_state = 42)

# %%
# Lets train the model
xgboost_classifier = xgb.XGBClassifier()
xgboost_classifier.fit(X_train, y_train)
predictions = xgboost_classifier.predict(X_test)
# Out:
# accuracy: 51.18%
#               precision    recall  f1-score   support
#
#            0       0.54      0.42      0.47       373
#            1       0.50      0.61      0.55       348
#
#    micro avg       0.51      0.51      0.51       721
#    macro avg       0.52      0.52      0.51       721
# weighted avg       0.52      0.51      0.51       721
#
# [[157 216]
#  [136 212]]

# %%
# Lets now take a look at some results
print('accuracy: {:.2f}%'.format(accuracy_score(y_test, predictions)*100))
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions, labels=[0, 1]))
# Out:
# accuracy: 51.18%
#               precision    recall  f1-score   support
#
#            0       0.54      0.42      0.47       373
#            1       0.50      0.61      0.55       348
#
#    micro avg       0.51      0.51      0.51       721
#    macro avg       0.52      0.52      0.51       721
# weighted avg       0.52      0.51      0.51       721
#
# [[157 216]
#  [136 212]]

# %%
# Lets get some feature importance plots
fig, ax = plt.subplots(figsize=(10, 10))
xgb.plot_importance(xgboost_classifier,max_num_features = 15, height = 0.5, ax = ax)

# %%
# We can now save the model for use in the production setting
#xgboost_classifier.save_model('relief_classifer')

pickle.dump(xgboost_classifier, open("classifier.pickle.dat", "wb"))

# %%
# Testing some hyper parameter tuning
cv = 10
paramGrid = {"subsample" : [0.5, 0.8]}

fit_params={ "eval_metric" : "mae", 
            "eval_set" : [[X_test, y_test]]}

model = xgb.XGBRegressor()
gridsearch = GridSearchCV(model, paramGrid, verbose=1 ,
         fit_params=fit_params,
         cv=TimeSeriesSplit(n_splits=cv).get_n_splits([X_train,y_train]))
gridsearch.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 2 candidates, totalling 20 fits
# [0]	validation_0-mae:0.499815
# [1]	validation_0-mae:0.499983
# [2]	validation_0-mae:0.500105
# [3]	validation_0-mae:0.499919
# [4]	validation_0-mae:0.500205
# [5]	validation_0-mae:0.500545
# [6]	validation_0-mae:0.500715
# [7]	validation_0-mae:0.500852
# [8]	validation_0-mae:0.500725
# [9]	validation_0-mae:0.500515
# [10]	validation_0-mae:0.500626
# [11]	validation_0-mae:0.500476
# [12]	validation_0-mae:0.500969
# [13]	validation_0-mae:0.500817
# [14]	validation_0-mae:0.50102
# [15]	validation_0-mae:0.500828
# [16]	validation_0-mae:0.500611
# [17]	validation_0-mae:0.500031
# [18]	validation_0-mae:0.500226
# [19]	validation_0-mae:0.500311
# [20]	validation_0-mae:0.500989
# [21]	validation_0-mae:0.500975
# [22]	validation_0-mae:0.500788
# [23]	validation_0-mae:0.501493
# [24]	validation_0-mae:0.501171
# [25]	validation_0-mae:0.501067
# [26]	validation_0-mae:0.501222
# [27]	validation_0-mae:0.501178
# [28]	validation_0-mae:0.501223
# [29]	validation_0-mae:0.501271
# [30]	validation_0-mae:0.501269
# [31]	validation_0-mae:0.501298
# [32]	validation_0-mae:0.50187
# [33]	validation_0-mae:0.501669
# [34]	validation_0-mae:0.501028
# [35]	validation_0-mae:0.501207
# [36]	validation_0-mae:0.501207
# [37]	validation_0-mae:0.501116
# [38]	validation_0-mae:0.501449
# [39]	validation_0-mae:0.50137
# [40]	validation_0-mae:0.501466
# [41]	validation_0-mae:0.501587
# [42]	validation_0-mae:0.501497
# [43]	validation_0-mae:0.501198
# [44]	validation_0-mae:0.501273
# [45]	validation_0-mae:0.501448
# [46]	validation_0-mae:0.5016
# [47]	validation_0-mae:0.501962
# [48]	validation_0-mae:0.50209
# [49]	validation_0-mae:0.502205
# [50]	validation_0-mae:0.502304
# [51]	validation_0-mae:0.501795
# [52]	validation_0-mae:0.501704
# [53]	validation_0-mae:0.50146
# [54]	validation_0-mae:0.50126
# [55]	validation_0-mae:0.501474
# [56]	validation_0-mae:0.501252
# [57]	validation_0-mae:0.501588
# [58]	validation_0-mae:0.502071
# [59]	validation_0-mae:0.501845
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:643: DeprecationWarning: "fit_params" as a constructor argument was deprecated in version 0.19 and will be removed in version 0.21. Pass fit parameters to the "fit" method instead.
#   '"fit" method instead.', DeprecationWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [60]	validation_0-mae:0.501788
# [61]	validation_0-mae:0.50186
# [62]	validation_0-mae:0.501752
# [63]	validation_0-mae:0.502097
# [64]	validation_0-mae:0.502288
# [65]	validation_0-mae:0.502549
# [66]	validation_0-mae:0.502795
# [67]	validation_0-mae:0.502112
# [68]	validation_0-mae:0.50212
# [69]	validation_0-mae:0.502225
# [70]	validation_0-mae:0.502177
# [71]	validation_0-mae:0.502156
# [72]	validation_0-mae:0.502078
# [73]	validation_0-mae:0.501934
# [74]	validation_0-mae:0.502091
# [75]	validation_0-mae:0.502123
# [76]	validation_0-mae:0.502665
# [77]	validation_0-mae:0.502784
# [78]	validation_0-mae:0.502882
# [79]	validation_0-mae:0.503176
# [80]	validation_0-mae:0.503297
# [81]	validation_0-mae:0.50324
# [82]	validation_0-mae:0.5033
# [83]	validation_0-mae:0.503559
# [84]	validation_0-mae:0.503312
# [85]	validation_0-mae:0.503564
# [86]	validation_0-mae:0.503896
# [87]	validation_0-mae:0.503712
# [88]	validation_0-mae:0.503737
# [89]	validation_0-mae:0.503837
# [90]	validation_0-mae:0.50385
# [91]	validation_0-mae:0.503298
# [92]	validation_0-mae:0.503375
# [93]	validation_0-mae:0.503232
# [94]	validation_0-mae:0.50333
# [95]	validation_0-mae:0.50351
# [96]	validation_0-mae:0.503507
# [97]	validation_0-mae:0.503046
# [98]	validation_0-mae:0.502921
# [99]	validation_0-mae:0.503022
# [0]	validation_0-mae:0.499879
# [1]	validation_0-mae:0.500084
# [2]	validation_0-mae:0.500179
# [3]	validation_0-mae:0.500219
# [4]	validation_0-mae:0.500386
# [5]	validation_0-mae:0.500348
# [6]	validation_0-mae:0.500123
# [7]	validation_0-mae:0.499867
# [8]	validation_0-mae:0.50022
# [9]	validation_0-mae:0.500596
# [10]	validation_0-mae:0.500647
# [11]	validation_0-mae:0.500403
# [12]	validation_0-mae:0.500158
# [13]	validation_0-mae:0.500065
# [14]	validation_0-mae:0.500021
# [15]	validation_0-mae:0.499944
# [16]	validation_0-mae:0.499813
# [17]	validation_0-mae:0.499655
# [18]	validation_0-mae:0.500114
# [19]	validation_0-mae:0.49968
# [20]	validation_0-mae:0.499517
# [21]	validation_0-mae:0.499754
# [22]	validation_0-mae:0.49951
# [23]	validation_0-mae:0.499323
# [24]	validation_0-mae:0.499345
# [25]	validation_0-mae:0.499084
# [26]	validation_0-mae:0.499189
# [27]	validation_0-mae:0.498885
# [28]	validation_0-mae:0.498728
# [29]	validation_0-mae:0.499059
# [30]	validation_0-mae:0.499315
# [31]	validation_0-mae:0.498911
# [32]	validation_0-mae:0.499098
# [33]	validation_0-mae:0.499048
# [34]	validation_0-mae:0.499152
# [35]	validation_0-mae:0.499091
# [36]	validation_0-mae:0.498845
# [37]	validation_0-mae:0.499086
# [38]	validation_0-mae:0.499389
# [39]	validation_0-mae:0.499232
# [40]	validation_0-mae:0.499435
# [41]	validation_0-mae:0.499184
# [42]	validation_0-mae:0.499349
# [43]	validation_0-mae:0.499472
# [44]	validation_0-mae:0.499506
# [45]	validation_0-mae:0.49919
# [46]	validation_0-mae:0.499242
# [47]	validation_0-mae:0.499419
# [48]	validation_0-mae:0.499413
# [49]	validation_0-mae:0.499029
# [50]	validation_0-mae:0.499581
# [51]	validation_0-mae:0.50013
# [52]	validation_0-mae:0.500465
# [53]	validation_0-mae:0.50091
# [54]	validation_0-mae:0.500291
# [55]	validation_0-mae:0.500224
# [56]	validation_0-mae:0.499846
# [57]	validation_0-mae:0.500099
# [58]	validation_0-mae:0.500055
# [59]	validation_0-mae:0.50017
# [60]	validation_0-mae:0.500495
# [61]	validation_0-mae:0.500564
# [62]	validation_0-mae:0.500928
# [63]	validation_0-mae:0.500999
# [64]	validation_0-mae:0.500952
# [65]	validation_0-mae:0.500686
# [66]	validation_0-mae:0.50038
# [67]	validation_0-mae:0.50001
# [68]	validation_0-mae:0.500323
# [69]	validation_0-mae:0.500766
# [70]	validation_0-mae:0.500839
# [71]	validation_0-mae:0.501081
# [72]	validation_0-mae:0.500637
# [73]	validation_0-mae:0.500221
# [74]	validation_0-mae:0.49993
# [75]	validation_0-mae:0.499656
# [76]	validation_0-mae:0.499947
# [77]	validation_0-mae:0.499588
# [78]	validation_0-mae:0.499131
# [79]	validation_0-mae:0.49938
# [80]	validation_0-mae:0.499044
# [81]	validation_0-mae:0.498879
# [82]	validation_0-mae:0.498983
# [83]	validation_0-mae:0.499138
# [84]	validation_0-mae:0.499214
# [85]	validation_0-mae:0.498775
# [86]	validation_0-mae:0.499059
# [87]	validation_0-mae:0.49933
# [88]	validation_0-mae:0.499442
# [89]	validation_0-mae:0.499372
# [90]	validation_0-mae:0.499616
# [91]	validation_0-mae:0.499625
# [92]	validation_0-mae:0.499436
# [93]	validation_0-mae:0.499529
# [94]	validation_0-mae:0.499156
# [95]	validation_0-mae:0.498926
# [96]	validation_0-mae:0.499109
# [97]	validation_0-mae:0.499195
# [98]	validation_0-mae:0.499576
# [99]	validation_0-mae:0.499551
# [0]	validation_0-mae:0.499866
# [1]	validation_0-mae:0.499686
# [2]	validation_0-mae:0.500185
# [3]	validation_0-mae:0.500457
# [4]	validation_0-mae:0.500418
# [5]	validation_0-mae:0.500271
# [6]	validation_0-mae:0.500771
# [7]	validation_0-mae:0.501029
# [8]	validation_0-mae:0.500591
# [9]	validation_0-mae:0.500226
# [10]	validation_0-mae:0.500109
# [11]	validation_0-mae:0.49985
# [12]	validation_0-mae:0.500235
# [13]	validation_0-mae:0.500102
# [14]	validation_0-mae:0.500227
# [15]	validation_0-mae:0.50048
# [16]	validation_0-mae:0.500478
# [17]	validation_0-mae:0.500041
# [18]	validation_0-mae:0.500863
# [19]	validation_0-mae:0.500565
# [20]	validation_0-mae:0.499927
# [21]	validation_0-mae:0.500107
# [22]	validation_0-mae:0.499575
# [23]	validation_0-mae:0.499182
# [24]	validation_0-mae:0.498988
# [25]	validation_0-mae:0.499637
# [26]	validation_0-mae:0.499893
# [27]	validation_0-mae:0.499924
# [28]	validation_0-mae:0.499747
# [29]	validation_0-mae:0.499786
# [30]	validation_0-mae:0.500401
# [31]	validation_0-mae:0.500215
# [32]	validation_0-mae:0.499942
# [33]	validation_0-mae:0.500032
# [34]	validation_0-mae:0.50008
# [35]	validation_0-mae:0.50046
# [36]	validation_0-mae:0.500123
# [37]	validation_0-mae:0.50011
# [38]	validation_0-mae:0.500659
# [39]	validation_0-mae:0.500206
# [40]	validation_0-mae:0.500325
# [41]	validation_0-mae:0.500743
# [42]	validation_0-mae:0.500962
# [43]	validation_0-mae:0.500667
# [44]	validation_0-mae:0.500713
# [45]	validation_0-mae:0.500655
# [46]	validation_0-mae:0.500537
# [47]	validation_0-mae:0.500549
# [48]	validation_0-mae:0.500321
# [49]	validation_0-mae:0.50022
# [50]	validation_0-mae:0.500659
# [51]	validation_0-mae:0.50088
# [52]	validation_0-mae:0.500714
# [53]	validation_0-mae:0.501187
# [54]	validation_0-mae:0.501145
# [55]	validation_0-mae:0.501341
# [56]	validation_0-mae:0.501208
# [57]	validation_0-mae:0.501476
# [58]	validation_0-mae:0.501222
# [59]	validation_0-mae:0.500848
# [60]	validation_0-mae:0.500589
# [61]	validation_0-mae:0.500743
# [62]	validation_0-mae:0.50117
# [63]	validation_0-mae:0.500949
# [64]	validation_0-mae:0.500876
# [65]	validation_0-mae:0.500744
# [66]	validation_0-mae:0.50077
# [67]	validation_0-mae:0.500587
# [68]	validation_0-mae:0.501068
# [69]	validation_0-mae:0.501646
# [70]	validation_0-mae:0.501556
# [71]	validation_0-mae:0.501387
# [72]	validation_0-mae:0.501143
# [73]	validation_0-mae:0.501188
# [74]	validation_0-mae:0.501088
# [75]	validation_0-mae:0.500947
# [76]	validation_0-mae:0.501324
# [77]	validation_0-mae:0.501095
# [78]	validation_0-mae:0.500899
# [79]	validation_0-mae:0.50067
# [80]	validation_0-mae:0.500336
# [81]	validation_0-mae:0.500286
# [82]	validation_0-mae:0.500628
# [83]	validation_0-mae:0.500887
# [84]	validation_0-mae:0.500902
# [85]	validation_0-mae:0.500721
# [86]	validation_0-mae:0.500672
# [87]	validation_0-mae:0.500789
# [88]	validation_0-mae:0.500892
# [89]	validation_0-mae:0.500854
# [90]	validation_0-mae:0.500916
# [91]	validation_0-mae:0.50085
# [92]	validation_0-mae:0.500774
# [93]	validation_0-mae:0.500406
# [94]	validation_0-mae:0.499958
# [95]	validation_0-mae:0.499646
# [96]	validation_0-mae:0.499566
# [97]	validation_0-mae:0.499611
# [98]	validation_0-mae:0.499865
# [99]	validation_0-mae:0.499796
# [0]	validation_0-mae:0.500306
# [1]	validation_0-mae:0.499973
# [2]	validation_0-mae:0.500138
# [3]	validation_0-mae:0.499697
# [4]	validation_0-mae:0.499831
# [5]	validation_0-mae:0.499664
# [6]	validation_0-mae:0.499933
# [7]	validation_0-mae:0.499955
# [8]	validation_0-mae:0.500497
# [9]	validation_0-mae:0.500979
# [10]	validation_0-mae:0.500892
# [11]	validation_0-mae:0.500812
# [12]	validation_0-mae:0.500785
# [13]	validation_0-mae:0.500915
# [14]	validation_0-mae:0.500805
# [15]	validation_0-mae:0.500923
# [16]	validation_0-mae:0.500748
# [17]	validation_0-mae:0.500908
# [18]	validation_0-mae:0.501553
# [19]	validation_0-mae:0.501199
# [20]	validation_0-mae:0.50113
# [21]	validation_0-mae:0.501178
# [22]	validation_0-mae:0.501027
# [23]	validation_0-mae:0.500602
# [24]	validation_0-mae:0.500872
# [25]	validation_0-mae:0.500766
# [26]	validation_0-mae:0.501015
# [27]	validation_0-mae:0.501456
# [28]	validation_0-mae:0.501702
# [29]	validation_0-mae:0.502299
# [30]	validation_0-mae:0.502768
# [31]	validation_0-mae:0.502603
# [32]	validation_0-mae:0.50239
# [33]	validation_0-mae:0.50266
# [34]	validation_0-mae:0.502714
# [35]	validation_0-mae:0.502932
# [36]	validation_0-mae:0.503404
# [37]	validation_0-mae:0.503388
# [38]	validation_0-mae:0.50386
# [39]	validation_0-mae:0.503327
# [40]	validation_0-mae:0.50308
# [41]	validation_0-mae:0.503177
# [42]	validation_0-mae:0.503281
# [43]	validation_0-mae:0.503184
# [44]	validation_0-mae:0.503136
# [45]	validation_0-mae:0.502483
# [46]	validation_0-mae:0.502618
# [47]	validation_0-mae:0.502602
# [48]	validation_0-mae:0.502974
# [49]	validation_0-mae:0.502757
# [50]	validation_0-mae:0.50306
# [51]	validation_0-mae:0.502942
# [52]	validation_0-mae:0.503448
# [53]	validation_0-mae:0.503764
# [54]	validation_0-mae:0.503713
# [55]	validation_0-mae:0.504286
# [56]	validation_0-mae:0.5042
# [57]	validation_0-mae:0.50426
# [58]	validation_0-mae:0.504276
# [59]	validation_0-mae:0.504325
# [60]	validation_0-mae:0.504532
# [61]	validation_0-mae:0.504577
# [62]	validation_0-mae:0.504708
# [63]	validation_0-mae:0.50423
# [64]	validation_0-mae:0.50392
# [65]	validation_0-mae:0.503822
# [66]	validation_0-mae:0.503932
# [67]	validation_0-mae:0.503382
# [68]	validation_0-mae:0.503496
# [69]	validation_0-mae:0.503763
# [70]	validation_0-mae:0.503665
# [71]	validation_0-mae:0.503878
# [72]	validation_0-mae:0.503859
# [73]	validation_0-mae:0.50383
# [74]	validation_0-mae:0.50359
# [75]	validation_0-mae:0.503439
# [76]	validation_0-mae:0.503665
# [77]	validation_0-mae:0.503466
# [78]	validation_0-mae:0.503798
# [79]	validation_0-mae:0.503852
# [80]	validation_0-mae:0.503518
# [81]	validation_0-mae:0.503832
# [82]	validation_0-mae:0.503905
# [83]	validation_0-mae:0.503446
# [84]	validation_0-mae:0.503644
# [85]	validation_0-mae:0.503566
# [86]	validation_0-mae:0.503828
# [87]	validation_0-mae:0.503873
# [88]	validation_0-mae:0.50389
# [89]	validation_0-mae:0.504019
# [90]	validation_0-mae:0.503671
# [91]	validation_0-mae:0.503597
# [92]	validation_0-mae:0.503311
# [93]	validation_0-mae:0.503202
# [94]	validation_0-mae:0.50302
# [95]	validation_0-mae:0.502748
# [96]	validation_0-mae:0.503061
# [97]	validation_0-mae:0.503046
# [98]	validation_0-mae:0.503327
# [99]	validation_0-mae:0.503647
# [0]	validation_0-mae:0.500113
# [1]	validation_0-mae:0.499986
# [2]	validation_0-mae:0.50002
# [3]	validation_0-mae:0.500042
# [4]	validation_0-mae:0.49984
# [5]	validation_0-mae:0.499834
# [6]	validation_0-mae:0.499979
# [7]	validation_0-mae:0.500043
# [8]	validation_0-mae:0.500572
# [9]	validation_0-mae:0.50105
# [10]	validation_0-mae:0.500952
# [11]	validation_0-mae:0.501087
# [12]	validation_0-mae:0.501057
# [13]	validation_0-mae:0.501106
# [14]	validation_0-mae:0.501189
# [15]	validation_0-mae:0.501281
# [16]	validation_0-mae:0.501401
# [17]	validation_0-mae:0.501142
# [18]	validation_0-mae:0.501545
# [19]	validation_0-mae:0.501586
# [20]	validation_0-mae:0.501719
# [21]	validation_0-mae:0.501636
# [22]	validation_0-mae:0.501601
# [23]	validation_0-mae:0.501397
# [24]	validation_0-mae:0.501892
# [25]	validation_0-mae:0.501989
# [26]	validation_0-mae:0.502027
# [27]	validation_0-mae:0.502033
# [28]	validation_0-mae:0.502175
# [29]	validation_0-mae:0.502373
# [30]	validation_0-mae:0.502669
# [31]	validation_0-mae:0.502446
# [32]	validation_0-mae:0.502342
# [33]	validation_0-mae:0.502452
# [34]	validation_0-mae:0.502452
# [35]	validation_0-mae:0.502603
# [36]	validation_0-mae:0.502703
# [37]	validation_0-mae:0.502836
# [38]	validation_0-mae:0.503036
# [39]	validation_0-mae:0.50354
# [40]	validation_0-mae:0.503773
# [41]	validation_0-mae:0.503654
# [42]	validation_0-mae:0.503609
# [43]	validation_0-mae:0.503532
# [44]	validation_0-mae:0.503582
# [45]	validation_0-mae:0.50363
# [46]	validation_0-mae:0.503858
# [47]	validation_0-mae:0.504036
# [48]	validation_0-mae:0.504225
# [49]	validation_0-mae:0.504269
# [50]	validation_0-mae:0.504117
# [51]	validation_0-mae:0.504123
# [52]	validation_0-mae:0.504013
# [53]	validation_0-mae:0.503827
# [54]	validation_0-mae:0.503359
# [55]	validation_0-mae:0.503583
# [56]	validation_0-mae:0.503883
# [57]	validation_0-mae:0.504387
# [58]	validation_0-mae:0.504126
# [59]	validation_0-mae:0.504481
# [60]	validation_0-mae:0.504375
# [61]	validation_0-mae:0.504605
# [62]	validation_0-mae:0.504584
# [63]	validation_0-mae:0.50419
# [64]	validation_0-mae:0.504504
# [65]	validation_0-mae:0.504576
# [66]	validation_0-mae:0.504409
# [67]	validation_0-mae:0.504515
# [68]	validation_0-mae:0.504321
# [69]	validation_0-mae:0.504571
# [70]	validation_0-mae:0.504311
# [71]	validation_0-mae:0.504248
# [72]	validation_0-mae:0.503934
# [73]	validation_0-mae:0.503724
# [74]	validation_0-mae:0.503784
# [75]	validation_0-mae:0.50351
# [76]	validation_0-mae:0.50404
# [77]	validation_0-mae:0.503928
# [78]	validation_0-mae:0.504226
# [79]	validation_0-mae:0.50444
# [80]	validation_0-mae:0.504631
# [81]	validation_0-mae:0.504733
# [82]	validation_0-mae:0.504428
# [83]	validation_0-mae:0.504566
# [84]	validation_0-mae:0.504925
# [85]	validation_0-mae:0.504615
# [86]	validation_0-mae:0.504664
# [87]	validation_0-mae:0.504394
# [88]	validation_0-mae:0.50461
# [89]	validation_0-mae:0.505198
# [90]	validation_0-mae:0.505452
# [91]	validation_0-mae:0.505117
# [92]	validation_0-mae:0.505251
# [93]	validation_0-mae:0.504935
# [94]	validation_0-mae:0.504656
# [95]	validation_0-mae:0.50437
# [96]	validation_0-mae:0.504758
# [97]	validation_0-mae:0.504742
# [98]	validation_0-mae:0.50526
# [99]	validation_0-mae:0.505248
# [0]	validation_0-mae:0.49996
# [1]	validation_0-mae:0.499682
# [2]	validation_0-mae:0.499627
# [3]	validation_0-mae:0.499274
# [4]	validation_0-mae:0.499054
# [5]	validation_0-mae:0.498818
# [6]	validation_0-mae:0.498637
# [7]	validation_0-mae:0.498794
# [8]	validation_0-mae:0.498362
# [9]	validation_0-mae:0.498401
# [10]	validation_0-mae:0.498435
# [11]	validation_0-mae:0.49805
# [12]	validation_0-mae:0.49781
# [13]	validation_0-mae:0.498003
# [14]	validation_0-mae:0.498162
# [15]	validation_0-mae:0.498444
# [16]	validation_0-mae:0.499191
# [17]	validation_0-mae:0.498785
# [18]	validation_0-mae:0.498826
# [19]	validation_0-mae:0.498678
# [20]	validation_0-mae:0.498934
# [21]	validation_0-mae:0.498637
# [22]	validation_0-mae:0.498782
# [23]	validation_0-mae:0.49856
# [24]	validation_0-mae:0.498705
# [25]	validation_0-mae:0.498513
# [26]	validation_0-mae:0.498888
# [27]	validation_0-mae:0.498768
# [28]	validation_0-mae:0.498524
# [29]	validation_0-mae:0.4986
# [30]	validation_0-mae:0.498875
# [31]	validation_0-mae:0.498706
# [32]	validation_0-mae:0.498661
# [33]	validation_0-mae:0.498713
# [34]	validation_0-mae:0.499042
# [35]	validation_0-mae:0.499054
# [36]	validation_0-mae:0.498853
# [37]	validation_0-mae:0.498806
# [38]	validation_0-mae:0.499121
# [39]	validation_0-mae:0.499348
# [40]	validation_0-mae:0.499233
# [41]	validation_0-mae:0.498671
# [42]	validation_0-mae:0.49864
# [43]	validation_0-mae:0.498374
# [44]	validation_0-mae:0.498306
# [45]	validation_0-mae:0.498217
# [46]	validation_0-mae:0.498348
# [47]	validation_0-mae:0.498597
# [48]	validation_0-mae:0.498868
# [49]	validation_0-mae:0.499159
# [50]	validation_0-mae:0.499496
# [51]	validation_0-mae:0.499339
# [52]	validation_0-mae:0.4996
# [53]	validation_0-mae:0.498855
# [54]	validation_0-mae:0.49917
# [55]	validation_0-mae:0.499391
# [56]	validation_0-mae:0.499487
# [57]	validation_0-mae:0.499769
# [58]	validation_0-mae:0.499521
# [59]	validation_0-mae:0.499747
# [60]	validation_0-mae:0.499748
# [61]	validation_0-mae:0.499573
# [62]	validation_0-mae:0.49938
# [63]	validation_0-mae:0.499544
# [64]	validation_0-mae:0.499588
# [65]	validation_0-mae:0.498874
# [66]	validation_0-mae:0.498749
# [67]	validation_0-mae:0.49913
# [68]	validation_0-mae:0.498727
# [69]	validation_0-mae:0.498666
# [70]	validation_0-mae:0.498451
# [71]	validation_0-mae:0.499006
# [72]	validation_0-mae:0.49929
# [73]	validation_0-mae:0.499391
# [74]	validation_0-mae:0.499645
# [75]	validation_0-mae:0.499811
# [76]	validation_0-mae:0.500225
# [77]	validation_0-mae:0.499865
# [78]	validation_0-mae:0.499775
# [79]	validation_0-mae:0.499622
# [80]	validation_0-mae:0.499902
# [81]	validation_0-mae:0.49984
# [82]	validation_0-mae:0.499531
# [83]	validation_0-mae:0.49919
# [84]	validation_0-mae:0.499369
# [85]	validation_0-mae:0.499167
# [86]	validation_0-mae:0.498724
# [87]	validation_0-mae:0.498626
# [88]	validation_0-mae:0.498851
# [89]	validation_0-mae:0.499171
# [90]	validation_0-mae:0.499542
# [91]	validation_0-mae:0.499103
# [92]	validation_0-mae:0.499083
# [93]	validation_0-mae:0.49892
# [94]	validation_0-mae:0.49874
# [95]	validation_0-mae:0.498892
# [96]	validation_0-mae:0.499303
# [97]	validation_0-mae:0.49953
# [98]	validation_0-mae:0.499585
# [99]	validation_0-mae:0.499171
# [0]	validation_0-mae:0.500055
# [1]	validation_0-mae:0.49975
# [2]	validation_0-mae:0.500239
# [3]	validation_0-mae:0.499847
# [4]	validation_0-mae:0.5002
# [5]	validation_0-mae:0.499996
# [6]	validation_0-mae:0.499991
# [7]	validation_0-mae:0.500144
# [8]	validation_0-mae:0.499867
# [9]	validation_0-mae:0.499509
# [10]	validation_0-mae:0.499343
# [11]	validation_0-mae:0.499098
# [12]	validation_0-mae:0.498859
# [13]	validation_0-mae:0.498415
# [14]	validation_0-mae:0.49859
# [15]	validation_0-mae:0.498463
# [16]	validation_0-mae:0.498184
# [17]	validation_0-mae:0.497724
# [18]	validation_0-mae:0.498528
# [19]	validation_0-mae:0.498265
# [20]	validation_0-mae:0.498019
# [21]	validation_0-mae:0.498222
# [22]	validation_0-mae:0.498428
# [23]	validation_0-mae:0.498449
# [24]	validation_0-mae:0.498561
# [25]	validation_0-mae:0.498623
# [26]	validation_0-mae:0.498677
# [27]	validation_0-mae:0.498537
# [28]	validation_0-mae:0.498655
# [29]	validation_0-mae:0.498553
# [30]	validation_0-mae:0.498595
# [31]	validation_0-mae:0.498485
# [32]	validation_0-mae:0.49798
# [33]	validation_0-mae:0.497988
# [34]	validation_0-mae:0.497959
# [35]	validation_0-mae:0.498144
# [36]	validation_0-mae:0.497973
# [37]	validation_0-mae:0.498236
# [38]	validation_0-mae:0.498515
# [39]	validation_0-mae:0.498746
# [40]	validation_0-mae:0.498856
# [41]	validation_0-mae:0.498828
# [42]	validation_0-mae:0.498937
# [43]	validation_0-mae:0.498587
# [44]	validation_0-mae:0.499089
# [45]	validation_0-mae:0.499185
# [46]	validation_0-mae:0.499718
# [47]	validation_0-mae:0.499641
# [48]	validation_0-mae:0.500174
# [49]	validation_0-mae:0.500407
# [50]	validation_0-mae:0.500197
# [51]	validation_0-mae:0.500195
# [52]	validation_0-mae:0.500582
# [53]	validation_0-mae:0.500636
# [54]	validation_0-mae:0.500683
# [55]	validation_0-mae:0.500946
# [56]	validation_0-mae:0.500739
# [57]	validation_0-mae:0.500843
# [58]	validation_0-mae:0.501081
# [59]	validation_0-mae:0.501362
# [60]	validation_0-mae:0.501233
# [61]	validation_0-mae:0.501248
# [62]	validation_0-mae:0.501311
# [63]	validation_0-mae:0.501309
# [64]	validation_0-mae:0.501384
# [65]	validation_0-mae:0.501514
# [66]	validation_0-mae:0.501605
# [67]	validation_0-mae:0.501632
# [68]	validation_0-mae:0.501321
# [69]	validation_0-mae:0.501507
# [70]	validation_0-mae:0.501108
# [71]	validation_0-mae:0.501209
# [72]	validation_0-mae:0.501392
# [73]	validation_0-mae:0.501887
# [74]	validation_0-mae:0.501816
# [75]	validation_0-mae:0.501774
# [76]	validation_0-mae:0.502146
# [77]	validation_0-mae:0.501695
# [78]	validation_0-mae:0.501469
# [79]	validation_0-mae:0.501696
# [80]	validation_0-mae:0.501555
# [81]	validation_0-mae:0.501376
# [82]	validation_0-mae:0.50088
# [83]	validation_0-mae:0.500867
# [84]	validation_0-mae:0.50099
# [85]	validation_0-mae:0.501156
# [86]	validation_0-mae:0.501214
# [87]	validation_0-mae:0.501425
# [88]	validation_0-mae:0.501596
# [89]	validation_0-mae:0.501634
# [90]	validation_0-mae:0.501438
# [91]	validation_0-mae:0.501253
# [92]	validation_0-mae:0.500879
# [93]	validation_0-mae:0.500915
# [94]	validation_0-mae:0.500663
# [95]	validation_0-mae:0.500583
# [96]	validation_0-mae:0.500681
# [97]	validation_0-mae:0.500806
# [98]	validation_0-mae:0.501003
# [99]	validation_0-mae:0.501116
# [0]	validation_0-mae:0.499942
# [1]	validation_0-mae:0.499737
# [2]	validation_0-mae:0.4997
# [3]	validation_0-mae:0.499412
# [4]	validation_0-mae:0.499811
# [5]	validation_0-mae:0.499758
# [6]	validation_0-mae:0.500273
# [7]	validation_0-mae:0.500537
# [8]	validation_0-mae:0.500402
# [9]	validation_0-mae:0.499746
# [10]	validation_0-mae:0.499831
# [11]	validation_0-mae:0.49999
# [12]	validation_0-mae:0.49971
# [13]	validation_0-mae:0.499691
# [14]	validation_0-mae:0.499492
# [15]	validation_0-mae:0.499457
# [16]	validation_0-mae:0.499349
# [17]	validation_0-mae:0.499127
# [18]	validation_0-mae:0.500047
# [19]	validation_0-mae:0.499801
# [20]	validation_0-mae:0.499416
# [21]	validation_0-mae:0.499772
# [22]	validation_0-mae:0.499872
# [23]	validation_0-mae:0.499791
# [24]	validation_0-mae:0.499877
# [25]	validation_0-mae:0.499881
# [26]	validation_0-mae:0.500018
# [27]	validation_0-mae:0.499782
# [28]	validation_0-mae:0.499742
# [29]	validation_0-mae:0.500027
# [30]	validation_0-mae:0.500394
# [31]	validation_0-mae:0.499912
# [32]	validation_0-mae:0.499641
# [33]	validation_0-mae:0.499594
# [34]	validation_0-mae:0.499565
# [35]	validation_0-mae:0.49949
# [36]	validation_0-mae:0.4992
# [37]	validation_0-mae:0.499875
# [38]	validation_0-mae:0.499802
# [39]	validation_0-mae:0.500049
# [40]	validation_0-mae:0.499939
# [41]	validation_0-mae:0.500059
# [42]	validation_0-mae:0.500417
# [43]	validation_0-mae:0.500405
# [44]	validation_0-mae:0.500511
# [45]	validation_0-mae:0.500228
# [46]	validation_0-mae:0.500729
# [47]	validation_0-mae:0.500655
# [48]	validation_0-mae:0.501068
# [49]	validation_0-mae:0.500862
# [50]	validation_0-mae:0.500606
# [51]	validation_0-mae:0.500733
# [52]	validation_0-mae:0.501098
# [53]	validation_0-mae:0.501315
# [54]	validation_0-mae:0.501043
# [55]	validation_0-mae:0.501221
# [56]	validation_0-mae:0.500851
# [57]	validation_0-mae:0.501362
# [58]	validation_0-mae:0.501778
# [59]	validation_0-mae:0.502159
# [60]	validation_0-mae:0.502439
# [61]	validation_0-mae:0.502313
# [62]	validation_0-mae:0.502018
# [63]	validation_0-mae:0.502096
# [64]	validation_0-mae:0.501545
# [65]	validation_0-mae:0.501578
# [66]	validation_0-mae:0.501364
# [67]	validation_0-mae:0.501424
# [68]	validation_0-mae:0.501455
# [69]	validation_0-mae:0.501064
# [70]	validation_0-mae:0.501108
# [71]	validation_0-mae:0.501238
# [72]	validation_0-mae:0.501102
# [73]	validation_0-mae:0.501273
# [74]	validation_0-mae:0.501097
# [75]	validation_0-mae:0.50119
# [76]	validation_0-mae:0.50216
# [77]	validation_0-mae:0.502198
# [78]	validation_0-mae:0.50244
# [79]	validation_0-mae:0.502646
# [80]	validation_0-mae:0.502604
# [81]	validation_0-mae:0.502206
# [82]	validation_0-mae:0.502123
# [83]	validation_0-mae:0.502045
# [84]	validation_0-mae:0.502551
# [85]	validation_0-mae:0.502472
# [86]	validation_0-mae:0.502188
# [87]	validation_0-mae:0.502663
# [88]	validation_0-mae:0.503073
# [89]	validation_0-mae:0.503017
# [90]	validation_0-mae:0.503093
# [91]	validation_0-mae:0.503355
# [92]	validation_0-mae:0.503251
# [93]	validation_0-mae:0.503186
# [94]	validation_0-mae:0.503205
# [95]	validation_0-mae:0.503405
# [96]	validation_0-mae:0.503417
# [97]	validation_0-mae:0.503448
# [98]	validation_0-mae:0.503254
# [99]	validation_0-mae:0.50286
# [0]	validation_0-mae:0.499718
# [1]	validation_0-mae:0.500448
# [2]	validation_0-mae:0.500251
# [3]	validation_0-mae:0.500354
# [4]	validation_0-mae:0.500815
# [5]	validation_0-mae:0.500547
# [6]	validation_0-mae:0.500567
# [7]	validation_0-mae:0.500768
# [8]	validation_0-mae:0.500243
# [9]	validation_0-mae:0.49991
# [10]	validation_0-mae:0.499278
# [11]	validation_0-mae:0.49973
# [12]	validation_0-mae:0.499987
# [13]	validation_0-mae:0.49997
# [14]	validation_0-mae:0.499724
# [15]	validation_0-mae:0.499764
# [16]	validation_0-mae:0.499826
# [17]	validation_0-mae:0.499609
# [18]	validation_0-mae:0.500258
# [19]	validation_0-mae:0.500243
# [20]	validation_0-mae:0.500082
# [21]	validation_0-mae:0.5004
# [22]	validation_0-mae:0.500514
# [23]	validation_0-mae:0.500363
# [24]	validation_0-mae:0.500681
# [25]	validation_0-mae:0.50044
# [26]	validation_0-mae:0.500011
# [27]	validation_0-mae:0.50017
# [28]	validation_0-mae:0.499888
# [29]	validation_0-mae:0.500206
# [30]	validation_0-mae:0.499937
# [31]	validation_0-mae:0.499987
# [32]	validation_0-mae:0.499745
# [33]	validation_0-mae:0.499728
# [34]	validation_0-mae:0.499346
# [35]	validation_0-mae:0.499191
# [36]	validation_0-mae:0.499089
# [37]	validation_0-mae:0.499226
# [38]	validation_0-mae:0.498377
# [39]	validation_0-mae:0.498524
# [40]	validation_0-mae:0.498358
# [41]	validation_0-mae:0.498284
# [42]	validation_0-mae:0.49818
# [43]	validation_0-mae:0.497891
# [44]	validation_0-mae:0.49789
# [45]	validation_0-mae:0.497757
# [46]	validation_0-mae:0.497383
# [47]	validation_0-mae:0.497326
# [48]	validation_0-mae:0.497413
# [49]	validation_0-mae:0.497428
# [50]	validation_0-mae:0.497077
# [51]	validation_0-mae:0.497203
# [52]	validation_0-mae:0.497644
# [53]	validation_0-mae:0.497784
# [54]	validation_0-mae:0.497834
# [55]	validation_0-mae:0.498053
# [56]	validation_0-mae:0.498034
# [57]	validation_0-mae:0.498324
# [58]	validation_0-mae:0.498423
# [59]	validation_0-mae:0.498832
# [60]	validation_0-mae:0.498922
# [61]	validation_0-mae:0.498754
# [62]	validation_0-mae:0.498791
# [63]	validation_0-mae:0.498487
# [64]	validation_0-mae:0.498885
# [65]	validation_0-mae:0.498864
# [66]	validation_0-mae:0.498621
# [67]	validation_0-mae:0.498693
# [68]	validation_0-mae:0.498709
# [69]	validation_0-mae:0.498681
# [70]	validation_0-mae:0.498618
# [71]	validation_0-mae:0.498639
# [72]	validation_0-mae:0.499087
# [73]	validation_0-mae:0.499005
# [74]	validation_0-mae:0.498984
# [75]	validation_0-mae:0.498826
# [76]	validation_0-mae:0.498648
# [77]	validation_0-mae:0.498799
# [78]	validation_0-mae:0.499015
# [79]	validation_0-mae:0.499035
# [80]	validation_0-mae:0.498954
# [81]	validation_0-mae:0.498787
# [82]	validation_0-mae:0.498474
# [83]	validation_0-mae:0.498698
# [84]	validation_0-mae:0.498842
# [85]	validation_0-mae:0.498651
# [86]	validation_0-mae:0.49859
# [87]	validation_0-mae:0.498677
# [88]	validation_0-mae:0.499326
# [89]	validation_0-mae:0.49911
# [90]	validation_0-mae:0.499235
# [91]	validation_0-mae:0.499252
# [92]	validation_0-mae:0.499072
# [93]	validation_0-mae:0.498814
# [94]	validation_0-mae:0.498709
# [95]	validation_0-mae:0.498975
# [96]	validation_0-mae:0.499334
# [97]	validation_0-mae:0.499771
# [98]	validation_0-mae:0.499821
# [99]	validation_0-mae:0.499279
# [0]	validation_0-mae:0.500116
# [1]	validation_0-mae:0.500717
# [2]	validation_0-mae:0.500696
# [3]	validation_0-mae:0.50068
# [4]	validation_0-mae:0.501186
# [5]	validation_0-mae:0.501092
# [6]	validation_0-mae:0.50102
# [7]	validation_0-mae:0.501002
# [8]	validation_0-mae:0.501686
# [9]	validation_0-mae:0.501316
# [10]	validation_0-mae:0.501132
# [11]	validation_0-mae:0.501008
# [12]	validation_0-mae:0.500791
# [13]	validation_0-mae:0.500922
# [14]	validation_0-mae:0.500691
# [15]	validation_0-mae:0.500748
# [16]	validation_0-mae:0.500999
# [17]	validation_0-mae:0.500754
# [18]	validation_0-mae:0.501538
# [19]	validation_0-mae:0.501268
# [20]	validation_0-mae:0.500946
# [21]	validation_0-mae:0.501114
# [22]	validation_0-mae:0.500812
# [23]	validation_0-mae:0.500817
# [24]	validation_0-mae:0.50123
# [25]	validation_0-mae:0.501397
# [26]	validation_0-mae:0.50132
# [27]	validation_0-mae:0.501379
# [28]	validation_0-mae:0.50133
# [29]	validation_0-mae:0.501657
# [30]	validation_0-mae:0.501652
# [31]	validation_0-mae:0.501728
# [32]	validation_0-mae:0.501754
# [33]	validation_0-mae:0.501845
# [34]	validation_0-mae:0.502074
# [35]	validation_0-mae:0.501909
# [36]	validation_0-mae:0.502115
# [37]	validation_0-mae:0.502402
# [38]	validation_0-mae:0.502707
# [39]	validation_0-mae:0.50251
# [40]	validation_0-mae:0.502616
# [41]	validation_0-mae:0.502794
# [42]	validation_0-mae:0.502418
# [43]	validation_0-mae:0.502471
# [44]	validation_0-mae:0.502083
# [45]	validation_0-mae:0.502175
# [46]	validation_0-mae:0.50231
# [47]	validation_0-mae:0.502338
# [48]	validation_0-mae:0.50222
# [49]	validation_0-mae:0.50169
# [50]	validation_0-mae:0.501454
# [51]	validation_0-mae:0.501515
# [52]	validation_0-mae:0.501779
# [53]	validation_0-mae:0.502058
# [54]	validation_0-mae:0.50212
# [55]	validation_0-mae:0.502104
# [56]	validation_0-mae:0.502046
# [57]	validation_0-mae:0.502547
# [58]	validation_0-mae:0.502829
# [59]	validation_0-mae:0.503055
# [60]	validation_0-mae:0.503266
# [61]	validation_0-mae:0.503248
# [62]	validation_0-mae:0.503538
# [63]	validation_0-mae:0.503033
# [64]	validation_0-mae:0.503228
# [65]	validation_0-mae:0.503301
# [66]	validation_0-mae:0.502819
# [67]	validation_0-mae:0.503013
# [68]	validation_0-mae:0.503338
# [69]	validation_0-mae:0.503368
# [70]	validation_0-mae:0.503059
# [71]	validation_0-mae:0.503408
# [72]	validation_0-mae:0.5036
# [73]	validation_0-mae:0.503262
# [74]	validation_0-mae:0.503059
# [75]	validation_0-mae:0.502984
# [76]	validation_0-mae:0.503293
# [77]	validation_0-mae:0.503039
# [78]	validation_0-mae:0.502901
# [79]	validation_0-mae:0.502676
# [80]	validation_0-mae:0.50309
# [81]	validation_0-mae:0.503075
# [82]	validation_0-mae:0.502693
# [83]	validation_0-mae:0.502689
# [84]	validation_0-mae:0.502837
# [85]	validation_0-mae:0.502708
# [86]	validation_0-mae:0.502799
# [87]	validation_0-mae:0.503308
# [88]	validation_0-mae:0.503232
# [89]	validation_0-mae:0.503603
# [90]	validation_0-mae:0.503501
# [91]	validation_0-mae:0.503504
# [92]	validation_0-mae:0.503312
# [93]	validation_0-mae:0.503419
# [94]	validation_0-mae:0.503414
# [95]	validation_0-mae:0.503639
# [96]	validation_0-mae:0.503643
# [97]	validation_0-mae:0.504
# [98]	validation_0-mae:0.504313
# [99]	validation_0-mae:0.504421
# [0]	validation_0-mae:0.500426
# [1]	validation_0-mae:0.500697
# [2]	validation_0-mae:0.500766
# [3]	validation_0-mae:0.500654
# [4]	validation_0-mae:0.501171
# [5]	validation_0-mae:0.501626
# [6]	validation_0-mae:0.501863
# [7]	validation_0-mae:0.501513
# [8]	validation_0-mae:0.501614
# [9]	validation_0-mae:0.501671
# [10]	validation_0-mae:0.501607
# [11]	validation_0-mae:0.501666
# [12]	validation_0-mae:0.50186
# [13]	validation_0-mae:0.501804
# [14]	validation_0-mae:0.501904
# [15]	validation_0-mae:0.501799
# [16]	validation_0-mae:0.501713
# [17]	validation_0-mae:0.501351
# [18]	validation_0-mae:0.501638
# [19]	validation_0-mae:0.501487
# [20]	validation_0-mae:0.501274
# [21]	validation_0-mae:0.501136
# [22]	validation_0-mae:0.501199
# [23]	validation_0-mae:0.501571
# [24]	validation_0-mae:0.501451
# [25]	validation_0-mae:0.501362
# [26]	validation_0-mae:0.501192
# [27]	validation_0-mae:0.501054
# [28]	validation_0-mae:0.501019
# [29]	validation_0-mae:0.501106
# [30]	validation_0-mae:0.501027
# [31]	validation_0-mae:0.500926
# [32]	validation_0-mae:0.50103
# [33]	validation_0-mae:0.501022
# [34]	validation_0-mae:0.500724
# [35]	validation_0-mae:0.500804
# [36]	validation_0-mae:0.500952
# [37]	validation_0-mae:0.500999
# [38]	validation_0-mae:0.50094
# [39]	validation_0-mae:0.501341
# [40]	validation_0-mae:0.50159
# [41]	validation_0-mae:0.502044
# [42]	validation_0-mae:0.502214
# [43]	validation_0-mae:0.5026
# [44]	validation_0-mae:0.502642
# [45]	validation_0-mae:0.502862
# [46]	validation_0-mae:0.502761
# [47]	validation_0-mae:0.502665
# [48]	validation_0-mae:0.502754
# [49]	validation_0-mae:0.502425
# [50]	validation_0-mae:0.502475
# [51]	validation_0-mae:0.502395
# [52]	validation_0-mae:0.502341
# [53]	validation_0-mae:0.502437
# [54]	validation_0-mae:0.502314
# [55]	validation_0-mae:0.502095
# [56]	validation_0-mae:0.502368
# [57]	validation_0-mae:0.502682
# [58]	validation_0-mae:0.502855
# [59]	validation_0-mae:0.503133
# [60]	validation_0-mae:0.503023
# [61]	validation_0-mae:0.503088
# [62]	validation_0-mae:0.503127
# [63]	validation_0-mae:0.503041
# [64]	validation_0-mae:0.503075
# [65]	validation_0-mae:0.503015
# [66]	validation_0-mae:0.502883
# [67]	validation_0-mae:0.50285
# [68]	validation_0-mae:0.503052
# [69]	validation_0-mae:0.503015
# [70]	validation_0-mae:0.502971
# [71]	validation_0-mae:0.502927
# [72]	validation_0-mae:0.503047
# [73]	validation_0-mae:0.503024
# [74]	validation_0-mae:0.503139
# [75]	validation_0-mae:0.503021
# [76]	validation_0-mae:0.502826
# [77]	validation_0-mae:0.50273
# [78]	validation_0-mae:0.502963
# [79]	validation_0-mae:0.503278
# [80]	validation_0-mae:0.50313
# [81]	validation_0-mae:0.503176
# [82]	validation_0-mae:0.503293
# [83]	validation_0-mae:0.503182
# [84]	validation_0-mae:0.502638
# [85]	validation_0-mae:0.502684
# [86]	validation_0-mae:0.502864
# [87]	validation_0-mae:0.502567
# [88]	validation_0-mae:0.502793
# [89]	validation_0-mae:0.502789
# [90]	validation_0-mae:0.502666
# [91]	validation_0-mae:0.502524
# [92]	validation_0-mae:0.502306
# [93]	validation_0-mae:0.502386
# [94]	validation_0-mae:0.50227
# [95]	validation_0-mae:0.502079
# [96]	validation_0-mae:0.501832
# [97]	validation_0-mae:0.501868
# [98]	validation_0-mae:0.501861
# [99]	validation_0-mae:0.501813
# [0]	validation_0-mae:0.500051
# [1]	validation_0-mae:0.500044
# [2]	validation_0-mae:0.500193
# [3]	validation_0-mae:0.50052
# [4]	validation_0-mae:0.500179
# [5]	validation_0-mae:0.499915
# [6]	validation_0-mae:0.499785
# [7]	validation_0-mae:0.500148
# [8]	validation_0-mae:0.499523
# [9]	validation_0-mae:0.499223
# [10]	validation_0-mae:0.499247
# [11]	validation_0-mae:0.499087
# [12]	validation_0-mae:0.49909
# [13]	validation_0-mae:0.4993
# [14]	validation_0-mae:0.499289
# [15]	validation_0-mae:0.499339
# [16]	validation_0-mae:0.499311
# [17]	validation_0-mae:0.499389
# [18]	validation_0-mae:0.499176
# [19]	validation_0-mae:0.498866
# [20]	validation_0-mae:0.498932
# [21]	validation_0-mae:0.499215
# [22]	validation_0-mae:0.49932
# [23]	validation_0-mae:0.499166
# [24]	validation_0-mae:0.499445
# [25]	validation_0-mae:0.49951
# [26]	validation_0-mae:0.499421
# [27]	validation_0-mae:0.499299
# [28]	validation_0-mae:0.49924
# [29]	validation_0-mae:0.499009
# [30]	validation_0-mae:0.498505
# [31]	validation_0-mae:0.498416
# [32]	validation_0-mae:0.498099
# [33]	validation_0-mae:0.498122
# [34]	validation_0-mae:0.498428
# [35]	validation_0-mae:0.49863
# [36]	validation_0-mae:0.499097
# [37]	validation_0-mae:0.499179
# [38]	validation_0-mae:0.499604
# [39]	validation_0-mae:0.499478
# [40]	validation_0-mae:0.499423
# [41]	validation_0-mae:0.499523
# [42]	validation_0-mae:0.499601
# [43]	validation_0-mae:0.49945
# [44]	validation_0-mae:0.499314
# [45]	validation_0-mae:0.499181
# [46]	validation_0-mae:0.499296
# [47]	validation_0-mae:0.499265
# [48]	validation_0-mae:0.499233
# [49]	validation_0-mae:0.499231
# [50]	validation_0-mae:0.499364
# [51]	validation_0-mae:0.499281
# [52]	validation_0-mae:0.499538
# [53]	validation_0-mae:0.499603
# [54]	validation_0-mae:0.49983
# [55]	validation_0-mae:0.500002
# [56]	validation_0-mae:0.499789
# [57]	validation_0-mae:0.499765
# [58]	validation_0-mae:0.499699
# [59]	validation_0-mae:0.4997
# [60]	validation_0-mae:0.499627
# [61]	validation_0-mae:0.499856
# [62]	validation_0-mae:0.499757
# [63]	validation_0-mae:0.499782
# [64]	validation_0-mae:0.499725
# [65]	validation_0-mae:0.499662
# [66]	validation_0-mae:0.499524
# [67]	validation_0-mae:0.499821
# [68]	validation_0-mae:0.499643
# [69]	validation_0-mae:0.499682
# [70]	validation_0-mae:0.500005
# [71]	validation_0-mae:0.5
# [72]	validation_0-mae:0.500053
# [73]	validation_0-mae:0.500308
# [74]	validation_0-mae:0.500266
# [75]	validation_0-mae:0.500086
# [76]	validation_0-mae:0.500021
# [77]	validation_0-mae:0.499774
# [78]	validation_0-mae:0.499743
# [79]	validation_0-mae:0.499635
# [80]	validation_0-mae:0.499789
# [81]	validation_0-mae:0.499655
# [82]	validation_0-mae:0.499494
# [83]	validation_0-mae:0.499689
# [84]	validation_0-mae:0.499897
# [85]	validation_0-mae:0.500005
# [86]	validation_0-mae:0.500055
# [87]	validation_0-mae:0.49995
# [88]	validation_0-mae:0.50003
# [89]	validation_0-mae:0.499978
# [90]	validation_0-mae:0.5001
# [91]	validation_0-mae:0.500012
# [92]	validation_0-mae:0.500018
# [93]	validation_0-mae:0.499737
# [94]	validation_0-mae:0.499625
# [95]	validation_0-mae:0.499868
# [96]	validation_0-mae:0.500042
# [97]	validation_0-mae:0.500486
# [98]	validation_0-mae:0.500558
# [99]	validation_0-mae:0.500394
# [0]	validation_0-mae:0.4999
# [1]	validation_0-mae:0.499975
# [2]	validation_0-mae:0.499935
# [3]	validation_0-mae:0.499535
# [4]	validation_0-mae:0.499712
# [5]	validation_0-mae:0.499331
# [6]	validation_0-mae:0.499961
# [7]	validation_0-mae:0.499678
# [8]	validation_0-mae:0.499605
# [9]	validation_0-mae:0.49943
# [10]	validation_0-mae:0.49965
# [11]	validation_0-mae:0.499403
# [12]	validation_0-mae:0.499486
# [13]	validation_0-mae:0.49951
# [14]	validation_0-mae:0.499687
# [15]	validation_0-mae:0.499988
# [16]	validation_0-mae:0.500318
# [17]	validation_0-mae:0.500263
# [18]	validation_0-mae:0.500868
# [19]	validation_0-mae:0.500623
# [20]	validation_0-mae:0.500669
# [21]	validation_0-mae:0.500672
# [22]	validation_0-mae:0.500842
# [23]	validation_0-mae:0.500412
# [24]	validation_0-mae:0.500465
# [25]	validation_0-mae:0.500052
# [26]	validation_0-mae:0.499813
# [27]	validation_0-mae:0.499779
# [28]	validation_0-mae:0.500329
# [29]	validation_0-mae:0.500405
# [30]	validation_0-mae:0.50028
# [31]	validation_0-mae:0.500349
# [32]	validation_0-mae:0.500307
# [33]	validation_0-mae:0.500207
# [34]	validation_0-mae:0.50013
# [35]	validation_0-mae:0.500038
# [36]	validation_0-mae:0.500237
# [37]	validation_0-mae:0.5001
# [38]	validation_0-mae:0.500386
# [39]	validation_0-mae:0.500321
# [40]	validation_0-mae:0.500048
# [41]	validation_0-mae:0.500315
# [42]	validation_0-mae:0.500434
# [43]	validation_0-mae:0.500567
# [44]	validation_0-mae:0.500634
# [45]	validation_0-mae:0.500478
# [46]	validation_0-mae:0.500595
# [47]	validation_0-mae:0.500293
# [48]	validation_0-mae:0.500229
# [49]	validation_0-mae:0.500122
# [50]	validation_0-mae:0.500392
# [51]	validation_0-mae:0.500257
# [52]	validation_0-mae:0.500203
# [53]	validation_0-mae:0.500135
# [54]	validation_0-mae:0.50018
# [55]	validation_0-mae:0.500826
# [56]	validation_0-mae:0.500667
# [57]	validation_0-mae:0.500524
# [58]	validation_0-mae:0.500377
# [59]	validation_0-mae:0.500415
# [60]	validation_0-mae:0.50051
# [61]	validation_0-mae:0.500676
# [62]	validation_0-mae:0.500819
# [63]	validation_0-mae:0.501324
# [64]	validation_0-mae:0.501407
# [65]	validation_0-mae:0.501301
# [66]	validation_0-mae:0.501038
# [67]	validation_0-mae:0.500925
# [68]	validation_0-mae:0.501045
# [69]	validation_0-mae:0.50093
# [70]	validation_0-mae:0.50059
# [71]	validation_0-mae:0.500457
# [72]	validation_0-mae:0.500611
# [73]	validation_0-mae:0.500436
# [74]	validation_0-mae:0.500382
# [75]	validation_0-mae:0.500266
# [76]	validation_0-mae:0.500244
# [77]	validation_0-mae:0.500067
# [78]	validation_0-mae:0.500057
# [79]	validation_0-mae:0.500095
# [80]	validation_0-mae:0.499926
# [81]	validation_0-mae:0.500067
# [82]	validation_0-mae:0.499941
# [83]	validation_0-mae:0.499959
# [84]	validation_0-mae:0.499958
# [85]	validation_0-mae:0.500063
# [86]	validation_0-mae:0.499839
# [87]	validation_0-mae:0.50023
# [88]	validation_0-mae:0.500555
# [89]	validation_0-mae:0.500461
# [90]	validation_0-mae:0.500372
# [91]	validation_0-mae:0.50023
# [92]	validation_0-mae:0.500359
# [93]	validation_0-mae:0.500305
# [94]	validation_0-mae:0.500059
# [95]	validation_0-mae:0.499979
# [96]	validation_0-mae:0.49989
# [97]	validation_0-mae:0.50004
# [98]	validation_0-mae:0.500182
# [99]	validation_0-mae:0.499999
# [0]	validation_0-mae:0.499842
# [1]	validation_0-mae:0.499616
# [2]	validation_0-mae:0.499117
# [3]	validation_0-mae:0.498989
# [4]	validation_0-mae:0.499424
# [5]	validation_0-mae:0.499206
# [6]	validation_0-mae:0.499265
# [7]	validation_0-mae:0.499511
# [8]	validation_0-mae:0.49936
# [9]	validation_0-mae:0.499362
# [10]	validation_0-mae:0.499837
# [11]	validation_0-mae:0.499649
# [12]	validation_0-mae:0.499563
# [13]	validation_0-mae:0.499821
# [14]	validation_0-mae:0.49972
# [15]	validation_0-mae:0.500036
# [16]	validation_0-mae:0.500021
# [17]	validation_0-mae:0.500254
# [18]	validation_0-mae:0.500257
# [19]	validation_0-mae:0.50025
# [20]	validation_0-mae:0.49997
# [21]	validation_0-mae:0.500031
# [22]	validation_0-mae:0.500227
# [23]	validation_0-mae:0.499938
# [24]	validation_0-mae:0.500047
# [25]	validation_0-mae:0.499447
# [26]	validation_0-mae:0.49938
# [27]	validation_0-mae:0.499806
# [28]	validation_0-mae:0.499836
# [29]	validation_0-mae:0.500085
# [30]	validation_0-mae:0.500089
# [31]	validation_0-mae:0.500369
# [32]	validation_0-mae:0.50068
# [33]	validation_0-mae:0.500765
# [34]	validation_0-mae:0.500811
# [35]	validation_0-mae:0.500978
# [36]	validation_0-mae:0.500904
# [37]	validation_0-mae:0.500518
# [38]	validation_0-mae:0.500513
# [39]	validation_0-mae:0.500767
# [40]	validation_0-mae:0.500596
# [41]	validation_0-mae:0.500814
# [42]	validation_0-mae:0.500912
# [43]	validation_0-mae:0.501063
# [44]	validation_0-mae:0.500756
# [45]	validation_0-mae:0.50085
# [46]	validation_0-mae:0.500622
# [47]	validation_0-mae:0.500639
# [48]	validation_0-mae:0.500818
# [49]	validation_0-mae:0.500661
# [50]	validation_0-mae:0.500642
# [51]	validation_0-mae:0.500619
# [52]	validation_0-mae:0.500948
# [53]	validation_0-mae:0.501209
# [54]	validation_0-mae:0.501178
# [55]	validation_0-mae:0.50138
# [56]	validation_0-mae:0.501392
# [57]	validation_0-mae:0.501319
# [58]	validation_0-mae:0.501192
# [59]	validation_0-mae:0.501079
# [60]	validation_0-mae:0.501113
# [61]	validation_0-mae:0.501477
# [62]	validation_0-mae:0.501603
# [63]	validation_0-mae:0.501938
# [64]	validation_0-mae:0.502042
# [65]	validation_0-mae:0.501626
# [66]	validation_0-mae:0.501576
# [67]	validation_0-mae:0.501562
# [68]	validation_0-mae:0.501441
# [69]	validation_0-mae:0.501325
# [70]	validation_0-mae:0.501329
# [71]	validation_0-mae:0.501161
# [72]	validation_0-mae:0.5013
# [73]	validation_0-mae:0.501486
# [74]	validation_0-mae:0.501458
# [75]	validation_0-mae:0.501209
# [76]	validation_0-mae:0.500961
# [77]	validation_0-mae:0.500946
# [78]	validation_0-mae:0.50103
# [79]	validation_0-mae:0.501289
# [80]	validation_0-mae:0.501185
# [81]	validation_0-mae:0.501206
# [82]	validation_0-mae:0.501075
# [83]	validation_0-mae:0.501107
# [84]	validation_0-mae:0.501102
# [85]	validation_0-mae:0.501393
# [86]	validation_0-mae:0.501715
# [87]	validation_0-mae:0.501566
# [88]	validation_0-mae:0.501588
# [89]	validation_0-mae:0.501797
# [90]	validation_0-mae:0.502032
# [91]	validation_0-mae:0.50219
# [92]	validation_0-mae:0.502231
# [93]	validation_0-mae:0.502158
# [94]	validation_0-mae:0.502086
# [95]	validation_0-mae:0.502049
# [96]	validation_0-mae:0.502348
# [97]	validation_0-mae:0.502384
# [98]	validation_0-mae:0.502358
# [99]	validation_0-mae:0.50235
# [0]	validation_0-mae:0.500165
# [1]	validation_0-mae:0.500282
# [2]	validation_0-mae:0.500072
# [3]	validation_0-mae:0.499892
# [4]	validation_0-mae:0.500313
# [5]	validation_0-mae:0.50055
# [6]	validation_0-mae:0.500238
# [7]	validation_0-mae:0.500659
# [8]	validation_0-mae:0.500038
# [9]	validation_0-mae:0.499798
# [10]	validation_0-mae:0.499765
# [11]	validation_0-mae:0.499849
# [12]	validation_0-mae:0.499935
# [13]	validation_0-mae:0.500012
# [14]	validation_0-mae:0.50025
# [15]	validation_0-mae:0.500464
# [16]	validation_0-mae:0.500607
# [17]	validation_0-mae:0.500411
# [18]	validation_0-mae:0.500463
# [19]	validation_0-mae:0.500209
# [20]	validation_0-mae:0.500225
# [21]	validation_0-mae:0.500312
# [22]	validation_0-mae:0.500054
# [23]	validation_0-mae:0.500139
# [24]	validation_0-mae:0.500245
# [25]	validation_0-mae:0.500145
# [26]	validation_0-mae:0.500319
# [27]	validation_0-mae:0.500563
# [28]	validation_0-mae:0.500841
# [29]	validation_0-mae:0.500813
# [30]	validation_0-mae:0.500615
# [31]	validation_0-mae:0.500887
# [32]	validation_0-mae:0.500561
# [33]	validation_0-mae:0.500567
# [34]	validation_0-mae:0.500633
# [35]	validation_0-mae:0.500709
# [36]	validation_0-mae:0.500595
# [37]	validation_0-mae:0.500716
# [38]	validation_0-mae:0.500792
# [39]	validation_0-mae:0.50087
# [40]	validation_0-mae:0.500485
# [41]	validation_0-mae:0.500491
# [42]	validation_0-mae:0.500434
# [43]	validation_0-mae:0.500307
# [44]	validation_0-mae:0.500264
# [45]	validation_0-mae:0.500084
# [46]	validation_0-mae:0.499655
# [47]	validation_0-mae:0.4994
# [48]	validation_0-mae:0.499641
# [49]	validation_0-mae:0.499361
# [50]	validation_0-mae:0.4995
# [51]	validation_0-mae:0.499727
# [52]	validation_0-mae:0.500048
# [53]	validation_0-mae:0.50038
# [54]	validation_0-mae:0.500634
# [55]	validation_0-mae:0.500822
# [56]	validation_0-mae:0.50049
# [57]	validation_0-mae:0.500382
# [58]	validation_0-mae:0.500421
# [59]	validation_0-mae:0.50035
# [60]	validation_0-mae:0.500409
# [61]	validation_0-mae:0.500406
# [62]	validation_0-mae:0.500447
# [63]	validation_0-mae:0.500716
# [64]	validation_0-mae:0.500689
# [65]	validation_0-mae:0.500305
# [66]	validation_0-mae:0.500512
# [67]	validation_0-mae:0.500586
# [68]	validation_0-mae:0.50065
# [69]	validation_0-mae:0.500543
# [70]	validation_0-mae:0.500157
# [71]	validation_0-mae:0.500219
# [72]	validation_0-mae:0.500409
# [73]	validation_0-mae:0.500418
# [74]	validation_0-mae:0.50055
# [75]	validation_0-mae:0.500464
# [76]	validation_0-mae:0.500328
# [77]	validation_0-mae:0.500059
# [78]	validation_0-mae:0.500106
# [79]	validation_0-mae:0.500288
# [80]	validation_0-mae:0.500133
# [81]	validation_0-mae:0.500169
# [82]	validation_0-mae:0.499914
# [83]	validation_0-mae:0.500016
# [84]	validation_0-mae:0.49981
# [85]	validation_0-mae:0.500137
# [86]	validation_0-mae:0.500002
# [87]	validation_0-mae:0.500022
# [88]	validation_0-mae:0.500228
# [89]	validation_0-mae:0.500391
# [90]	validation_0-mae:0.500597
# [91]	validation_0-mae:0.50055
# [92]	validation_0-mae:0.500579
# [93]	validation_0-mae:0.50062
# [94]	validation_0-mae:0.500867
# [95]	validation_0-mae:0.500816
# [96]	validation_0-mae:0.501162
# [97]	validation_0-mae:0.501194
# [98]	validation_0-mae:0.501165
# [99]	validation_0-mae:0.5013
# [0]	validation_0-mae:0.499582
# [1]	validation_0-mae:0.49954
# [2]	validation_0-mae:0.499364
# [3]	validation_0-mae:0.498973
# [4]	validation_0-mae:0.499003
# [5]	validation_0-mae:0.499137
# [6]	validation_0-mae:0.499113
# [7]	validation_0-mae:0.499452
# [8]	validation_0-mae:0.499524
# [9]	validation_0-mae:0.499152
# [10]	validation_0-mae:0.499667
# [11]	validation_0-mae:0.499613
# [12]	validation_0-mae:0.499864
# [13]	validation_0-mae:0.499867
# [14]	validation_0-mae:0.499569
# [15]	validation_0-mae:0.499549
# [16]	validation_0-mae:0.499531
# [17]	validation_0-mae:0.499411
# [18]	validation_0-mae:0.499953
# [19]	validation_0-mae:0.499887
# [20]	validation_0-mae:0.499838
# [21]	validation_0-mae:0.499647
# [22]	validation_0-mae:0.499477
# [23]	validation_0-mae:0.499306
# [24]	validation_0-mae:0.499216
# [25]	validation_0-mae:0.499101
# [26]	validation_0-mae:0.498966
# [27]	validation_0-mae:0.498954
# [28]	validation_0-mae:0.498989
# [29]	validation_0-mae:0.498849
# [30]	validation_0-mae:0.498791
# [31]	validation_0-mae:0.499372
# [32]	validation_0-mae:0.49911
# [33]	validation_0-mae:0.498936
# [34]	validation_0-mae:0.499052
# [35]	validation_0-mae:0.499114
# [36]	validation_0-mae:0.498974
# [37]	validation_0-mae:0.498909
# [38]	validation_0-mae:0.498817
# [39]	validation_0-mae:0.498957
# [40]	validation_0-mae:0.49889
# [41]	validation_0-mae:0.499077
# [42]	validation_0-mae:0.499219
# [43]	validation_0-mae:0.499063
# [44]	validation_0-mae:0.49883
# [45]	validation_0-mae:0.498794
# ...
# [17]	validation_0-mae:0.500347
# [18]	validation_0-mae:0.500767
# [19]	validation_0-mae:0.500695
# [20]	validation_0-mae:0.500653
# [21]	validation_0-mae:0.500378
# [22]	validation_0-mae:0.500304
# [23]	validation_0-mae:0.499891
# [24]	validation_0-mae:0.499914
# [25]	validation_0-mae:0.499907
# [26]	validation_0-mae:0.499911
# [27]	validation_0-mae:0.50016
# [28]	validation_0-mae:0.500392
# [29]	validation_0-mae:0.500162
# [30]	validation_0-mae:0.49997
# [31]	validation_0-mae:0.500292
# [32]	validation_0-mae:0.500104
# [33]	validation_0-mae:0.500261
# [34]	validation_0-mae:0.500166
# [35]	validation_0-mae:0.500148
# [36]	validation_0-mae:0.500306
# [37]	validation_0-mae:0.500418
# [38]	validation_0-mae:0.500126
# [39]	validation_0-mae:0.500451
# [40]	validation_0-mae:0.500398
# [41]	validation_0-mae:0.50034
# [42]	validation_0-mae:0.500425
# [43]	validation_0-mae:0.500215
# [44]	validation_0-mae:0.499872
# [45]	validation_0-mae:0.500197
# [46]	validation_0-mae:0.500188
# [47]	validation_0-mae:0.500188
# [48]	validation_0-mae:0.500582
# [49]	validation_0-mae:0.500558
# [50]	validation_0-mae:0.500597
# [51]	validation_0-mae:0.500636
# [52]	validation_0-mae:0.500488
# [53]	validation_0-mae:0.500873
# [54]	validation_0-mae:0.501036
# [55]	validation_0-mae:0.500961
# [56]	validation_0-mae:0.501094
# [57]	validation_0-mae:0.501218
# [58]	validation_0-mae:0.501006
# [59]	validation_0-mae:0.501169
# [60]	validation_0-mae:0.501216
# [61]	validation_0-mae:0.501382
# [62]	validation_0-mae:0.501446
# [63]	validation_0-mae:0.501687
# [64]	validation_0-mae:0.501755
# [65]	validation_0-mae:0.501781
# [66]	validation_0-mae:0.501974
# [67]	validation_0-mae:0.502017
# [68]	validation_0-mae:0.50182
# [69]	validation_0-mae:0.501888
# [70]	validation_0-mae:0.501731
# [71]	validation_0-mae:0.501958
# [72]	validation_0-mae:0.502176
# [73]	validation_0-mae:0.502598
# [74]	validation_0-mae:0.50271
# [75]	validation_0-mae:0.502631
# [76]	validation_0-mae:0.502704
# [77]	validation_0-mae:0.502562
# [78]	validation_0-mae:0.502312
# [79]	validation_0-mae:0.502332
# [80]	validation_0-mae:0.502287
# [81]	validation_0-mae:0.502279
# [82]	validation_0-mae:0.50217
# [83]	validation_0-mae:0.502121
# [84]	validation_0-mae:0.502397
# [85]	validation_0-mae:0.502717
# [86]	validation_0-mae:0.502543
# [87]	validation_0-mae:0.502566
# [88]	validation_0-mae:0.502454
# [89]	validation_0-mae:0.502772
# [90]	validation_0-mae:0.502686
# [91]	validation_0-mae:0.50275
# [92]	validation_0-mae:0.502831
# [93]	validation_0-mae:0.502872
# [94]	validation_0-mae:0.502724
# [95]	validation_0-mae:0.502689
# [96]	validation_0-mae:0.502804
# [97]	validation_0-mae:0.50296
# [98]	validation_0-mae:0.503354
# [99]	validation_0-mae:0.503382
# [0]	validation_0-mae:0.499677
# [1]	validation_0-mae:0.499727
# [2]	validation_0-mae:0.499336
# [3]	validation_0-mae:0.499021
# [4]	validation_0-mae:0.499237
# [5]	validation_0-mae:0.499268
# [6]	validation_0-mae:0.499081
# [7]	validation_0-mae:0.499297
# [8]	validation_0-mae:0.499213
# [9]	validation_0-mae:0.499083
# [10]	validation_0-mae:0.499252
# [11]	validation_0-mae:0.499101
# [12]	validation_0-mae:0.498838
# [13]	validation_0-mae:0.499223
# [14]	validation_0-mae:0.498961
# [15]	validation_0-mae:0.499162
# [16]	validation_0-mae:0.499267
# [17]	validation_0-mae:0.499495
# [18]	validation_0-mae:0.499858
# [19]	validation_0-mae:0.499671
# [20]	validation_0-mae:0.49987
# [21]	validation_0-mae:0.499985
# [22]	validation_0-mae:0.500099
# [23]	validation_0-mae:0.500191
# [24]	validation_0-mae:0.500232
# [25]	validation_0-mae:0.500634
# [26]	validation_0-mae:0.500394
# [27]	validation_0-mae:0.500408
# [28]	validation_0-mae:0.500418
# [29]	validation_0-mae:0.500093
# [30]	validation_0-mae:0.500028
# [31]	validation_0-mae:0.500122
# [32]	validation_0-mae:0.499983
# [33]	validation_0-mae:0.499933
# [34]	validation_0-mae:0.49966
# [35]	validation_0-mae:0.499767
# [36]	validation_0-mae:0.499559
# [37]	validation_0-mae:0.499485
# [38]	validation_0-mae:0.499611
# [39]	validation_0-mae:0.499712
# [40]	validation_0-mae:0.499731
# [41]	validation_0-mae:0.500153
# [42]	validation_0-mae:0.500459
# [43]	validation_0-mae:0.500148
# [44]	validation_0-mae:0.500169
# [45]	validation_0-mae:0.500088
# [46]	validation_0-mae:0.500121
# [47]	validation_0-mae:0.500438
# [48]	validation_0-mae:0.500507
# [49]	validation_0-mae:0.500299
# [50]	validation_0-mae:0.500192
# [51]	validation_0-mae:0.500352
# [52]	validation_0-mae:0.500213
# [53]	validation_0-mae:0.500062
# [54]	validation_0-mae:0.500219
# [55]	validation_0-mae:0.500224
# [56]	validation_0-mae:0.50043
# [57]	validation_0-mae:0.500665
# [58]	validation_0-mae:0.500806
# [59]	validation_0-mae:0.500997
# [60]	validation_0-mae:0.500992
# [61]	validation_0-mae:0.501
# [62]	validation_0-mae:0.500885
# [63]	validation_0-mae:0.50091
# [64]	validation_0-mae:0.501133
# [65]	validation_0-mae:0.501148
# [66]	validation_0-mae:0.501141
# [67]	validation_0-mae:0.50119
# [68]	validation_0-mae:0.500863
# [69]	validation_0-mae:0.500829
# [70]	validation_0-mae:0.500723
# [71]	validation_0-mae:0.500878
# [72]	validation_0-mae:0.501012
# [73]	validation_0-mae:0.501006
# [74]	validation_0-mae:0.501133
# [75]	validation_0-mae:0.501184
# [76]	validation_0-mae:0.501435
# [77]	validation_0-mae:0.501301
# [78]	validation_0-mae:0.501074
# [79]	validation_0-mae:0.501265
# [80]	validation_0-mae:0.501078
# [81]	validation_0-mae:0.501072
# [82]	validation_0-mae:0.5009
# [83]	validation_0-mae:0.500913
# [84]	validation_0-mae:0.500927
# [85]	validation_0-mae:0.500954
# [86]	validation_0-mae:0.500918
# [87]	validation_0-mae:0.500852
# [88]	validation_0-mae:0.500723
# [89]	validation_0-mae:0.500906
# [90]	validation_0-mae:0.500697
# [91]	validation_0-mae:0.500855
# [92]	validation_0-mae:0.500835
# [93]	validation_0-mae:0.5008
# [94]	validation_0-mae:0.500957
# [95]	validation_0-mae:0.501075
# [96]	validation_0-mae:0.501128
# [97]	validation_0-mae:0.501178
# [98]	validation_0-mae:0.501392
# [99]	validation_0-mae:0.501352
# [0]	validation_0-mae:0.499716
# [1]	validation_0-mae:0.499885
# [2]	validation_0-mae:0.499717
# [3]	validation_0-mae:0.499643
# [4]	validation_0-mae:0.499761
# [5]	validation_0-mae:0.499841
# [6]	validation_0-mae:0.499531
# [7]	validation_0-mae:0.499632
# [8]	validation_0-mae:0.499918
# [9]	validation_0-mae:0.499413
# [10]	validation_0-mae:0.499015
# [11]	validation_0-mae:0.498984
# [12]	validation_0-mae:0.498863
# [13]	validation_0-mae:0.498908
# [14]	validation_0-mae:0.498618
# [15]	validation_0-mae:0.498791
# [16]	validation_0-mae:0.498953
# [17]	validation_0-mae:0.499277
# [18]	validation_0-mae:0.499516
# [19]	validation_0-mae:0.49961
# [20]	validation_0-mae:0.499628
# [21]	validation_0-mae:0.499885
# [22]	validation_0-mae:0.500077
# [23]	validation_0-mae:0.500169
# [24]	validation_0-mae:0.500419
# [25]	validation_0-mae:0.500246
# [26]	validation_0-mae:0.500413
# [27]	validation_0-mae:0.500545
# [28]	validation_0-mae:0.500555
# [29]	validation_0-mae:0.500459
# [30]	validation_0-mae:0.499965
# [31]	validation_0-mae:0.500004
# [32]	validation_0-mae:0.49975
# [33]	validation_0-mae:0.499582
# [34]	validation_0-mae:0.499417
# [35]	validation_0-mae:0.499606
# [36]	validation_0-mae:0.499584
# [37]	validation_0-mae:0.499703
# [38]	validation_0-mae:0.499991
# [39]	validation_0-mae:0.500087
# [40]	validation_0-mae:0.500075
# [41]	validation_0-mae:0.500175
# [42]	validation_0-mae:0.500109
# [43]	validation_0-mae:0.499721
# [44]	validation_0-mae:0.499885
# [45]	validation_0-mae:0.499739
# [46]	validation_0-mae:0.49946
# [47]	validation_0-mae:0.499521
# [48]	validation_0-mae:0.499477
# [49]	validation_0-mae:0.499191
# [50]	validation_0-mae:0.499163
# [51]	validation_0-mae:0.499355
# [52]	validation_0-mae:0.499235
# [53]	validation_0-mae:0.499491
# [54]	validation_0-mae:0.499333
# [55]	validation_0-mae:0.499489
# [56]	validation_0-mae:0.499963
# [57]	validation_0-mae:0.499808
# [58]	validation_0-mae:0.500067
# [59]	validation_0-mae:0.499996
# [60]	validation_0-mae:0.499947
# [61]	validation_0-mae:0.500113
# [62]	validation_0-mae:0.500054
# [63]	validation_0-mae:0.500033
# [64]	validation_0-mae:0.500228
# [65]	validation_0-mae:0.500348
# [66]	validation_0-mae:0.500181
# [67]	validation_0-mae:0.50027
# [68]	validation_0-mae:0.500244
# [69]	validation_0-mae:0.500206
# [70]	validation_0-mae:0.500279
# [71]	validation_0-mae:0.500371
# [72]	validation_0-mae:0.500629
# [73]	validation_0-mae:0.500688
# [74]	validation_0-mae:0.500745
# [75]	validation_0-mae:0.500681
# [76]	validation_0-mae:0.500667
# [77]	validation_0-mae:0.500746
# [78]	validation_0-mae:0.500798
# [79]	validation_0-mae:0.500835
# [80]	validation_0-mae:0.500692
# [81]	validation_0-mae:0.500609
# [82]	validation_0-mae:0.500614
# [83]	validation_0-mae:0.500439
# [84]	validation_0-mae:0.5005
# [85]	validation_0-mae:0.500469
# [86]	validation_0-mae:0.500685
# [87]	validation_0-mae:0.500611
# [88]	validation_0-mae:0.500393
# [89]	validation_0-mae:0.500552
# [90]	validation_0-mae:0.500468
# [91]	validation_0-mae:0.500462
# [92]	validation_0-mae:0.500486
# [93]	validation_0-mae:0.500574
# [94]	validation_0-mae:0.500449
# [95]	validation_0-mae:0.500332
# [96]	validation_0-mae:0.500581
# [97]	validation_0-mae:0.500802
# [98]	validation_0-mae:0.500742
# [99]	validation_0-mae:0.500702
# [0]	validation_0-mae:0.500217
# [1]	validation_0-mae:0.500307
# [2]	validation_0-mae:0.500059
# [3]	validation_0-mae:0.49997
# [4]	validation_0-mae:0.500024
# [5]	validation_0-mae:0.499996
# [6]	validation_0-mae:0.499626
# [7]	validation_0-mae:0.499764
# [8]	validation_0-mae:0.499708
# [9]	validation_0-mae:0.499608
# [10]	validation_0-mae:0.499541
# [11]	validation_0-mae:0.499662
# [12]	validation_0-mae:0.499467
# [13]	validation_0-mae:0.499496
# [14]	validation_0-mae:0.499003
# [15]	validation_0-mae:0.498921
# [16]	validation_0-mae:0.499271
# [17]	validation_0-mae:0.499618
# [18]	validation_0-mae:0.500054
# [19]	validation_0-mae:0.499646
# [20]	validation_0-mae:0.499491
# [21]	validation_0-mae:0.499292
# [22]	validation_0-mae:0.499162
# [23]	validation_0-mae:0.499143
# [24]	validation_0-mae:0.499281
# [25]	validation_0-mae:0.49951
# [26]	validation_0-mae:0.499646
# [27]	validation_0-mae:0.499679
# [28]	validation_0-mae:0.499731
# [29]	validation_0-mae:0.499779
# [30]	validation_0-mae:0.499737
# [31]	validation_0-mae:0.499676
# [32]	validation_0-mae:0.499539
# [33]	validation_0-mae:0.499304
# [34]	validation_0-mae:0.499231
# [35]	validation_0-mae:0.499331
# [36]	validation_0-mae:0.499309
# [37]	validation_0-mae:0.499192
# [38]	validation_0-mae:0.499313
# [39]	validation_0-mae:0.499279
# [40]	validation_0-mae:0.499295
# [41]	validation_0-mae:0.499536
# [42]	validation_0-mae:0.499481
# [43]	validation_0-mae:0.499063
# [44]	validation_0-mae:0.498904
# [45]	validation_0-mae:0.498862
# [46]	validation_0-mae:0.49879
# [47]	validation_0-mae:0.498935
# [48]	validation_0-mae:0.499197
# [49]	validation_0-mae:0.499116
# [50]	validation_0-mae:0.499214
# [51]	validation_0-mae:0.498963
# [52]	validation_0-mae:0.498882
# [53]	validation_0-mae:0.499084
# [54]	validation_0-mae:0.499216
# [55]	validation_0-mae:0.499553
# [56]	validation_0-mae:0.499876
# [57]	validation_0-mae:0.500189
# [58]	validation_0-mae:0.500202
# [59]	validation_0-mae:0.500501
# [60]	validation_0-mae:0.500913
# [61]	validation_0-mae:0.501038
# [62]	validation_0-mae:0.500902
# [63]	validation_0-mae:0.500719
# [64]	validation_0-mae:0.500835
# [65]	validation_0-mae:0.500877
# [66]	validation_0-mae:0.500533
# [67]	validation_0-mae:0.500814
# [68]	validation_0-mae:0.500822
# [69]	validation_0-mae:0.500969
# [70]	validation_0-mae:0.500885
# [71]	validation_0-mae:0.5009
# [72]	validation_0-mae:0.501062
# [73]	validation_0-mae:0.501085
# [74]	validation_0-mae:0.501248
# [75]	validation_0-mae:0.501181
# [76]	validation_0-mae:0.500967
# [77]	validation_0-mae:0.500808
# [78]	validation_0-mae:0.500761
# [79]	validation_0-mae:0.500991
# [80]	validation_0-mae:0.50098
# [81]	validation_0-mae:0.501162
# [82]	validation_0-mae:0.501297
# [83]	validation_0-mae:0.50122
# [84]	validation_0-mae:0.501265
# [85]	validation_0-mae:0.501406
# [86]	validation_0-mae:0.501679
# [87]	validation_0-mae:0.501947
# [88]	validation_0-mae:0.502338
# [89]	validation_0-mae:0.502209
# [90]	validation_0-mae:0.502014
# [91]	validation_0-mae:0.501945
# [92]	validation_0-mae:0.501853
# [93]	validation_0-mae:0.501647
# [94]	validation_0-mae:0.501648
# [95]	validation_0-mae:0.50171
# [96]	validation_0-mae:0.502006
# [97]	validation_0-mae:0.502412
# [98]	validation_0-mae:0.502601
# [99]	validation_0-mae:0.502553
# [0]	validation_0-mae:0.50001
# [1]	validation_0-mae:0.499679
# [2]	validation_0-mae:0.499356
# [3]	validation_0-mae:0.499422
# [4]	validation_0-mae:0.499306
# [5]	validation_0-mae:0.499603
# [6]	validation_0-mae:0.499397
# [7]	validation_0-mae:0.499386
# [8]	validation_0-mae:0.499196
# [9]	validation_0-mae:0.498999
# [10]	validation_0-mae:0.498884
# [11]	validation_0-mae:0.498869
# [12]	validation_0-mae:0.499021
# [13]	validation_0-mae:0.498983
# [14]	validation_0-mae:0.498687
# [15]	validation_0-mae:0.499094
# [16]	validation_0-mae:0.499276
# [17]	validation_0-mae:0.499522
# [18]	validation_0-mae:0.499767
# [19]	validation_0-mae:0.499671
# [20]	validation_0-mae:0.499812
# [21]	validation_0-mae:0.499733
# [22]	validation_0-mae:0.4997
# [23]	validation_0-mae:0.499812
# [24]	validation_0-mae:0.500191
# [25]	validation_0-mae:0.500175
# [26]	validation_0-mae:0.499845
# [27]	validation_0-mae:0.499466
# [28]	validation_0-mae:0.499502
# [29]	validation_0-mae:0.499431
# [30]	validation_0-mae:0.499479
# [31]	validation_0-mae:0.499483
# [32]	validation_0-mae:0.499248
# [33]	validation_0-mae:0.499023
# [34]	validation_0-mae:0.499021
# [35]	validation_0-mae:0.498773
# [36]	validation_0-mae:0.498889
# [37]	validation_0-mae:0.499382
# [38]	validation_0-mae:0.499498
# [39]	validation_0-mae:0.499425
# [40]	validation_0-mae:0.499214
# [41]	validation_0-mae:0.499181
# [42]	validation_0-mae:0.499603
# [43]	validation_0-mae:0.499824
# [44]	validation_0-mae:0.500102
# [45]	validation_0-mae:0.500267
# [46]	validation_0-mae:0.500368
# [47]	validation_0-mae:0.500412
# [48]	validation_0-mae:0.500271
# [49]	validation_0-mae:0.500345
# [50]	validation_0-mae:0.500611
# [51]	validation_0-mae:0.500812
# [52]	validation_0-mae:0.501091
# [53]	validation_0-mae:0.500871
# [54]	validation_0-mae:0.500892
# [55]	validation_0-mae:0.501093
# [56]	validation_0-mae:0.501334
# [57]	validation_0-mae:0.500975
# [58]	validation_0-mae:0.500859
# [59]	validation_0-mae:0.500863
# [60]	validation_0-mae:0.500692
# [61]	validation_0-mae:0.500831
# [62]	validation_0-mae:0.5009
# [63]	validation_0-mae:0.501057
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    6.0s finished
# [64]	validation_0-mae:0.501346
# [65]	validation_0-mae:0.501416
# [66]	validation_0-mae:0.501343
# [67]	validation_0-mae:0.501277
# [68]	validation_0-mae:0.501279
# [69]	validation_0-mae:0.501192
# [70]	validation_0-mae:0.501286
# [71]	validation_0-mae:0.501072
# [72]	validation_0-mae:0.501246
# [73]	validation_0-mae:0.501226
# [74]	validation_0-mae:0.501171
# [75]	validation_0-mae:0.501365
# [76]	validation_0-mae:0.501375
# [77]	validation_0-mae:0.501348
# [78]	validation_0-mae:0.501521
# [79]	validation_0-mae:0.50155
# [80]	validation_0-mae:0.501722
# [81]	validation_0-mae:0.501766
# [82]	validation_0-mae:0.501752
# [83]	validation_0-mae:0.501901
# [84]	validation_0-mae:0.501959
# [85]	validation_0-mae:0.502084
# [86]	validation_0-mae:0.501999
# [87]	validation_0-mae:0.502061
# [88]	validation_0-mae:0.502236
# [89]	validation_0-mae:0.502458
# [90]	validation_0-mae:0.502522
# [91]	validation_0-mae:0.502659
# [92]	validation_0-mae:0.502623
# [93]	validation_0-mae:0.502697
# [94]	validation_0-mae:0.502787
# [95]	validation_0-mae:0.50261
# [96]	validation_0-mae:0.502737
# [97]	validation_0-mae:0.502758
# [98]	validation_0-mae:0.502892
# [99]	validation_0-mae:0.502982
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params={'eval_metric': 'mae', 'eval_set': [[      hybrid  sativa  indica  thc_percent  cbd_percent  avg_subjectivity  \
# 471      1.0     0.0     0.0     1.000000     0.020951          1.000000
# 1453     1.0     0.0     0.0     0.000000     0.579428          0.000000
# 2379     1.0     0.0    ...13    1
# 1090    1
# 1512    1
# 630     1
# 2509    1
# 1385    1
# Name: relief, Length: 721, dtype: int64]]},
#        iid='warn', n_jobs=None, param_grid={'subsample': [0.5, 0.8]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %% [markdown]
# #### We can additionally try to solve this problem using a Multi lyer perceptron (Loss of explainability but potentially better results)

# %%
mlp = MLPClassifier(hidden_layer_sizes=(28,32,28),max_iter=500)
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(28, 32, 28), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=500, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
predictions = mlp.predict(X_test)

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[211 162]
#  [201 147]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.57      0.54       373
#            1       0.48      0.42      0.45       348
#
#    micro avg       0.50      0.50      0.50       721
#    macro avg       0.49      0.49      0.49       721
# weighted avg       0.49      0.50      0.49       721

# %% [markdown]
# ###### Here we can see that since the data is randomly generated, the results dont change much from XGBoost. Parameter tuning on both these models are futile until real world data that exhibits trends can be fed into the training phases

# %%
loaded_model = pickle.load(open("classifier.pickle.dat", "rb"))
print(loaded_model.score(X_test,y_test))
# Out:
# 0.5117891816920943

# %%
predictions = loaded_model.predict(X_test)
print('accuracy: {:.2f}%'.format(accuracy_score(y_test, predictions)*100))
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions, labels=[0, 1]))
# Out:
# accuracy: 51.18%
#               precision    recall  f1-score   support
#
#            0       0.54      0.42      0.47       373
#            1       0.50      0.61      0.55       348
#
#    micro avg       0.51      0.51      0.51       721
#    macro avg       0.52      0.52      0.51       721
# weighted avg       0.52      0.51      0.51       721
#
# [[157 216]
#  [136 212]]

# %%
print(predictions[0])
# Out:
# 1
